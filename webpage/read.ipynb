# %%
import numpy as np
import pandas as pd

# %%
df[['PATIENTHASHMRN','ENCDATEDIFFNO','DEIDENTIFIED_TEXT']]
# Out:
#                                          PATIENTHASHMRN  ENCDATEDIFFNO  \
# 0     4c52ca6379edc6b75bad9860ed7257e2332e7d5c6a8749...        27255.0
# 1     150de55917b0310f1b07ad4351df440a574e86d43296e2...        27089.0
# 2     15cf4a5b81485de0b1890bed6e9a1c3def23012c1f5104...        27588.0
# 3     2e302daa4eb84caae6d06ba70534c618494d6c68dc3cc3...        27294.0
# 4     a3d09b9e8d1e69837ba3fafebe705f5ef9f853af17b148...        27007.0
# ...                                                 ...            ...
# 1267  6b253c527513241ac21ef2f5cb203d538e0ca1bfa222fa...        28294.0
# 1268  e57cd9b2ec8deaa29b5e3bcd60fcb88719523c1c805f0d...        28543.0
# 1269  3d5248dd4e86dbbbc375f857455b2e44945803d3b6b78b...        28362.0
# 1270  e8211930da30598ab3ea599665110e3285f07a9ca09a61...        28435.0
# 1271  da079d5c3eccdefce202d126a9ef5d8dac7f32a64c24c5...        28533.0
#
#                                       DEIDENTIFIED_TEXT
# 0     Subjective     Chief Complaint(s)  Follow-up (...
# ...

# %%
df = pd.read_csv("Asthma_Symp.csv")
# data_dict = dict(zip(df["index"], df["DEIDENTIFIED_TEXT"]))

# %%
print("DATA = {")
for key, value in data_dict.items():
    # Escape any triple quotes inside the text just in case
    safe_value = value.replace('"""', '\\"\\"\\"')
    print(f"    {key}: \"\"\"{safe_value}\"\"\",")
print("}")
